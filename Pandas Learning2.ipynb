# %%
import pandas as pd

# %%
df = pd.read_csv('Data/survey_results_public.csv', index_col='Respondent')
pd.set_option('display.max_columns', 100)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df['Age1stCode'].value_counts()
# Out:
# 15    5618
# 14    5514
# 16    5463
# 18    5382
# 12    5081
#       ...
# 68       1
# 63       1
# 72       1
# 76       1
# 83       1
# Name: Age1stCode, Length: 63, dtype: int64

# %%
df.dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# Age1stCode                       object
# CompFreq                         object
# CompTotal                       float64
# ConvertedComp                   float64
# Country                          object
# CurrencyDesc                     object
# CurrencySymbol                   object
# DatabaseDesireNextYear           object
# DatabaseWorkedWith               object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# JobSeek                          object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 65639                  I am a student who is learning to code       No   NaN
# 65637                  I am a student who is learning to code      Yes   NaN
# 65636                          I am a developer by profession      Yes   NaN
# 65635                          I am a developer by profession      Yes   NaN
# 65634                          I am a developer by profession      Yes   NaN
# ...                                                       ...      ...   ...
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 4                              I am a developer by profession      Yes  25.0
# 3                                 I code primarily as a hobby      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 1                              I am a developer by profession      Yes   NaN
#
# ...

# %%
import numpy as np
#'Younger than 5 years'
#'Older than 85'
#nan
df['Age1stCode'].replace({'Younger than 5 years' : 4, 'Older than 85': 86, np.nan : 0}, inplace=True)

# %%
df['Age1stCode'] = df['Age1stCode'].astype(int)

# %%
junior = df['Age1stCode'] <= 12
subjunior = (df['Age1stCode'] > 12) & (df['Age1stCode'] <= 20)
senior = (df['Age1stCode'] > 20)

# %%
print(junior.sum())
print(subjunior.sum())
print(senior.sum())
# Out:
# 22605
# 35710
# 6146

# %%
df['UndergradMajor'].str.contains('informa', na = False).sum()
# Out:
# 4071

# %%
df['CurrencyDesc'].astype(str).apply(str.upper)
# Out:
# Respondent
# 1         EUROPEAN EURO
# 2        POUND STERLING
# 3                   NAN
# 4          ALBANIAN LEK
# 5                   NAN
#               ...
# 64858               NAN
# 64867               NAN
# 64898               NAN
# 64925               NAN
# 65112               NAN
# Name: CurrencyDesc, Length: 64461, dtype: object

# %%
df.drop(columns = ['CurrencyDesc'])
df.append({'Respondent': 7382349, 'MainBranch': "I am awesome"}, ignore_index=True)
df.sort_values(by='Respondent', ascending = False)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 65639                  I am a student who is learning to code       No   NaN
# 65637                  I am a student who is learning to code      Yes   NaN
# 65636                          I am a developer by profession      Yes   NaN
# 65635                          I am a developer by profession      Yes   NaN
# 65634                          I am a developer by profession      Yes   NaN
# ...                                                       ...      ...   ...
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 4                              I am a developer by profession      Yes  25.0
# 3                                 I code primarily as a hobby      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 1                              I am a developer by profession      Yes   NaN
#
# ...

# %%
df['Age1stCode'].describe()
# Out:
# count    64461.000000
# mean        13.841842
# std          6.846523
# min          0.000000
# 25%         11.000000
# 50%         14.000000
# 75%         18.000000
# max         86.000000
# Name: Age1stCode, dtype: float64

# %%
cgrp = df.groupby(['Country'])
cgrp['Age1stCode'].value_counts(normalize=True).loc['United States']
# Out:
# Age1stCode
# 12    0.100970
# 15    0.079397
# 13    0.079317
# 10    0.076670
# 14    0.076109
# 16    0.075066
# 18    0.066966
# 0     0.054856
# 11    0.047237
# 17    0.045312
# 8     0.041864
# 19    0.037292
# 9     0.028711
# 20    0.027027
# 7     0.022135
# 21    0.017644
# 22    0.013794
# 6     0.013554
# 25    0.013233
# 23    0.011228
# 24    0.009223
# 26    0.008020
# 5     0.007058
# 4     0.006576
# 30    0.006095
# 27    0.006015
# 28    0.004892
# 29    0.004732
# 31    0.002807
# 35    0.002486
# 32    0.002165
# 33    0.002085
# 34    0.001444
# 40    0.001123
# 36    0.001043
# 38    0.000722
# 37    0.000642
# 45    0.000642
# 39    0.000561
# 50    0.000561
# 41    0.000401
# 47    0.000321
# 49    0.000321
# 44    0.000241
# 51    0.000241
# 54    0.000241
# 42    0.000160
# 55    0.000160
# 43    0.000080
# 46    0.000080
# 52    0.000080
# 53    0.000080
# 56    0.000080
# 58    0.000080
# 64    0.000080
# 86    0.000080
# Name: Age1stCode, dtype: float64

# %%
cgrp['Age1stCode'].agg(['mean', 'median', 'std'])
# Out:
#                                            mean  median        std
# Country
# Afghanistan                            9.202381     7.5   8.643933
# Albania                               13.777778    16.0   7.735404
# Algeria                               14.308511    17.5   8.707958
# Andorra                               12.692308     6.0  23.264367
# Angola                                 6.555556     0.0   9.125666
# ...                                         ...     ...        ...
# Venezuela, Bolivarian Republic of...  16.071429    16.0   7.512929
# Viet Nam                              12.582418    15.0  10.178101
# Yemen                                 14.142857    10.0  13.246743
# Zambia                                16.238095    19.0  10.094081
# Zimbabwe                              15.548387    19.0   8.309989
#
# [183 rows x 3 columns]

# %%
df.dropna(axis = 'columns', how = 'all')
df[df['Hobbyist'].isna()]
# Out:
#                                                    MainBranch Hobbyist  Age  \
# Respondent
# 35499                          I am a developer by profession      NaN  NaN
# 35728       I am not primarily a developer, but I write co...      NaN  NaN
# 35912       I am not primarily a developer, but I write co...      NaN  NaN
# 35985                          I am a developer by profession      NaN  NaN
# 36374       I am not primarily a developer, but I write co...      NaN  NaN
# 36538                          I am a developer by profession      NaN  NaN
# 36763                          I am a developer by profession      NaN  NaN
# 36868                  I am a student who is learning to code      NaN  NaN
# 37029                          I am a developer by profession      NaN  NaN
# 37242                          I am a developer by profession      NaN  NaN
# 37751                          I am a developer by profession      NaN  NaN
# ...
