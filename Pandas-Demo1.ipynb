# %%
import pandas as pd

# %%
df = pd.read_csv('Data/survey_results_public.csv')

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
schema_df = pd.read_csv('Data/survey_results_schema.csv', index_col='Column')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
filt =  df['LanguageWorkedWith'].str.contains('Java', na=True)

# %%
filt.value_counts()
# Out:
# True     52832
# False    11629
# Name: LanguageWorkedWith, dtype: int64

# %%
df.columns = [col.upper() for col in list(df.columns)]

# %%
df1.apply(len, axis = 'columns')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-11079245dc66> in <module>
# ----> 1 df1.apply(len, axis = 'columns')
#
# NameError: name 'df1' is not defined

# %%
df1

# %%
dfx = pd.DataFrame()

# %%
dfx

# %%
dfx.append(['5,10,15'])

# %%
dfx

# %%
dfx.append(['5', '10', '15'])

# %%
dfx = dfx.append([['hello', 'world'], ['mark'], ['five']])

# %%
filt = dfx[0] == 'hello'

# %%
dfx[filt].index

# %%
dfx.index

# %%
dfx[0] = "Hello"

# %%
dfx.iloc[0] = ["Assuew", "welord", "poelo"]

# %%
dfx

# %%
a = ['name', 'age']

# %%
b = ['naren', 23]

# %%
dfx = pd.DataFrame(columns = ['year','make','model'])

# %%
dfx[dfx['model'] == 'Accord2']

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
country_grp = df.groupby('Country')
#country_grp['LanguageWorkedWith'].value_counts()
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
pyth_users = country_grp['LanguageWorkedWith'].agg(['count', lambda x: x.str.contains('Python').sum()])
pyth_users = pyth_users.rename(columns = {'count':'Total Users', '<lambda_0>':'Python Users'})
pyth_users['Pyth_Percentage'] = pyth_users['Python Users'] * 100 / pyth_users['Total Users']
min_users = pyth_users['Total Users'] > 100
pyth_users[min_users].sort_values(by='Pyth_Percentage', ascending=False)
# Out:
#                     Total Users  Python Users  Pyth_Percentage
# Country
# Finland                     333           183        54.954955
# China                       294           158        53.741497
# Taiwan                      136            73        53.676471
# Israel                      593           307        51.770658
# United States             11633          5964        51.267945
# Japan                       260           132        50.769231
# Estonia                     131            65        49.618321
# Canada                     2038          1011        49.607458
# Ireland                     407           199        48.894349
# France                     1724           833        48.317865
# Singapore                   206            99        48.058252
# Kenya                       234           111        47.435897
# Switzerland                 588           278        47.278912
# Germany                    3633          1712        47.123589
# ...

# %%
pyth_users.loc['India']
# Out:
# Total Users        6884.00000
# Python Users       2670.00000
# Pyth_Percentage      38.78559
# Name: India, dtype: float64

# %% [markdown]
# #### Cleaning data

# %%
#Cleaning Rows with NA

dfx = pd.DataFrame({'First': ['Naren', 'Syed'], 'Last': ['Mohan', 'Jweria']})

# %%
dfx.dtypes
# Out:
# First    object
# Last     object
# dtype: object

# %%
df['Age'].replace(np.nan, 0.0, inplace=True)
df['Age'].astype(int).mode()
# Out:
# 0    0
# dtype: int32

# %%
import numpy as np

# %%
df['YearsCode'].replace('36', '0').unique()
# Out:
# array(['0', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 0, '3', '13', '25', '16', '43',
#        '11', '38', '33', nan, '24', '21', '12', '40', '27', '50', '46',
#        '14', '18', '28', '32', '44', '26', '42', '31', '34', '29', '1',
#        '39', '41', '45', 'More than 50 years', '47', '49', '48'],
#       dtype=object)

# %%
df2 = df.set_index('YearsCode')
df2.dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# Age1stCode                       object
# CompFreq                         object
# CompTotal                       float64
# ConvertedComp                   float64
# Country                          object
# CurrencyDesc                     object
# CurrencySymbol                   object
# DatabaseDesireNextYear           object
# DatabaseWorkedWith               object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# JobSeek                          object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# ...
